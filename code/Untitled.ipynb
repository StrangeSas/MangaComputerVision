# %%
cock_img = cv2.imread("../db/cola.png")

# %%
print(cock_img.shape)
print(cock_img.dtype)
# Out:
# (300, 300, 3)
# uint8

# %%
coke_img_channels_reversed = cock_img[:,:,::-1]

# %%
plt.imshow(cock_img)

# %%
cock_img = cv2.imread("../db/makima.png")

# %%
img_manga__gray = cv2.imread("../db/makima.png", cv2.IMREAD_GRAYSCALE)
thresh = 240
im_bw = cv2.threshold(img_manga__gray, thresh, 255, cv2.THRESH_BINARY)[1]

img_adap = cv2.adaptiveThreshold(img_manga__gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,7)

plt.imshow(im_bw);plt.title('gray image')

cv2.imwrite('bw_image.png', im_bw)
# Out:
# True

# %%
img_manga_bgr = cv2.imread("../db/makima.png", cv2.IMREAD_COLOR)
b_ma, g_ma, r_ma = cv2.split(img_manga_bgr)

plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(r_ma);plt.title('red channel')
plt.subplot(142);plt.imshow(g_ma);plt.title('green channel')
plt.subplot(143);plt.imshow(b_ma);plt.title('blue channel')

im_merged_ma = cv2.merge((b_ma,g_ma,r_ma))


plt.subplot(144);plt.imshow(im_merged_ma[:,:,::-1]);plt.title('full image')
# Out:
# Text(0.5, 1.0, 'full image')

# %%
img_manga_bgr = cv2.imread("../db/balls.jpg", cv2.IMREAD_COLOR)
b, g, r = cv2.split(img_manga_bgr)

plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(r);plt.title('red channel')
plt.subplot(142);plt.imshow(g);plt.title('green channel')
plt.subplot(143);plt.imshow(b);plt.title('blue channel')

im_merged_ma = cv2.merge((b,g,r))

im_merged_rgb = cv2.cvtColor(im_merged_ma, cv2.COLOR_BGR2RGB)
plt.subplot(144);plt.imshow(im_merged_rgb);plt.title('full image')
# Out:
# Text(0.5, 1.0, 'full image')

# %%
img_manga_bgr = cv2.imread("../db/makima.png", cv2.IMREAD_COLOR)
img_manga_bgr = cv2.cvtColor(img_manga_bgr, cv2.COLOR_BGR2HSV)
h, s, v = cv2.split(img_manga_bgr)

plt.figure(figsize=[20,5])
plt.subplot(141);plt.imshow(h);plt.title('red channel')
plt.subplot(142);plt.imshow(s);plt.title('green channel')
plt.subplot(143);plt.imshow(v);plt.title('blue channel')

im_merged_ma = cv2.merge((h,s,v))

plt.subplot(144);plt.imshow(im_merged_ma);plt.title('full image')
# Out:
# Text(0.5, 1.0, 'full image')

# %%
cock_img = cv2.imread("../db/cola.png", 0)
plt.imshow(cock_img, cmap='gray')
print(cock_img)
# Out:
# [[89 90 90 ... 90 90 89]
#  [89 92 91 ... 91 92 89]
#  [90 91 90 ... 90 91 89]
#  ...
#  [90 91 90 ... 90 91 89]
#  [90 91 90 ... 90 91 89]
#  [90 90 90 ... 90 90 90]]

# %%
cock_img_copy = cock_img.copy()
cock_img_copy[40,40] = 200
cock_img_copy[40,41] = 200
cock_img_copy[40,42] = 200
cock_img_copy[40,43] = 200
cock_img_copy[40,44] = 200
cock_img_copy[40,45] = 200
cock_img_copy[41,45] = 200
cock_img_copy[39,45] = 200


plt.imshow(cock_img_copy, cmap='gray')
print(cock_img_copy)
# Out:
# [[89 90 90 ... 90 90 89]
#  [89 92 91 ... 91 92 89]
#  [90 91 90 ... 90 91 89]
#  ...
#  [90 91 90 ... 90 91 89]
#  [90 91 90 ... 90 91 89]
#  [90 90 90 ... 90 90 90]]

# %%
image_bgr = cv2.imread('../db/buba.png', cv2.IMREAD_COLOR)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# %%
matrix = np.ones(image_rgb.shape, dtype='uint8') * 50

img_rgb_brighter = cv2.add(image_rgb, matrix)
img_rgb_darker = cv2.subtract(image_rgb, matrix)

plt.figure(figsize=[18,5])
plt.subplot(131);plt.imshow(img_rgb_brighter);plt.title('bright')
plt.subplot(132);plt.imshow(image_rgb);plt.title('norm')
plt.subplot(133);plt.imshow(img_rgb_darker);plt.title('dark')
# Out:
# Text(0.5, 1.0, 'dark')

# %%
matrix1 = np.ones(image_rgb.shape) * .2
matrix2 = np.ones(image_rgb.shape) * 1.9

img_rgb_brighter = np.uint8(cv2.multiply(np.float64(image_rgb), matrix1))
img_rgb_darker = np.uint8(cv2.multiply(np.float64(image_rgb), matrix2))

plt.figure(figsize=[18,5])
plt.subplot(131);plt.imshow(img_rgb_brighter);plt.title('bright')
plt.subplot(132);plt.imshow(image_rgb);plt.title('norm')
plt.subplot(133);plt.imshow(img_rgb_darker);plt.title('dark')
# Out:
# Text(0.5, 1.0, 'dark')

# %%
img_manga_bgr = cv2.imread("../db/cola.png", cv2.IMREAD_COLOR)
img_manga_rgb = cv2.cvtColor(img_manga_bgr, cv2.COLOR_BGR2RGB)
logo_w = img_manga_rgb.shape[0]
logo_h = img_manga_rgb.shape[1]

# %%
image_bgr = cv2.imread('../db/isle.png', cv2.IMREAD_COLOR)
aspect_ratio = logo_w / image_bgr.shape[1]
dim = (logo_w, logo_h)
image_bgr = cv2.resize(image_bgr, dim, interpolation = cv2.INTER_AREA)
img_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# %%
print(img_manga_rgb.shape)
print(img_rgb.shape)
# Out:
# (300, 300, 3)
# (300, 300, 3)

# %%
plt.imshow(img_rgb)

# %%
img_gray = cv2.cvtColor(img_manga_rgb, cv2.COLOR_RGB2GRAY)
retval, img_mask = cv2.threshold(img_gray, 127, 255, cv2.THRESH_BINARY)

print(img_mask.shape)
# Out:
# (300, 300)

# %%
img_mask_inv = cv2.bitwise_not(img_mask)
plt.imshow(img_mask_inv, cmap='gray')

# %%
img_background = cv2.bitwise_and(img_rgb, img_rgb, mask = img_mask_inv)

plt.imshow(img_background)

# %%
from pytesseract import pytesseract

# %%
pytesseract.tesseract_cmd  = r"/usr/bin/tesseract"

# %%
plt.imshow(img_manga__gray)

# %%
img_manga__gray = cv2.imread("../db/makima.png", cv2.IMREAD_GRAYSCALE)
thresh = 140
im_bw = cv2.threshold(img_manga__gray, thresh, 255, cv2.THRESH_BINARY)[1]

img_adap = cv2.adaptiveThreshold(img_manga__gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,7)

plt.imshow(im_bw);plt.title('gray image')
# Out:
# Text(0.5, 1.0, 'gray image')

# %%
#51:31

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %%
img_manga__gray = cv2.imread("../db/makima.png", cv2.IMREAD_GRAYSCALE)
words_in_image = pytesseract.image_to_string(im_bw)
print(words_in_image)

words_in_image = pytesseract.image_to_string(im_bw)
print(words_in_image)
# Out:
#
#
#
#
#
# WMakima
# is.
# listening

# %%
words_in_image = pytesseract.image_to_string(im_bw)
print(words_in_image)
# Out:
#
#
#
#
#
# WMakima
# is.
# listening

# %%
#Что нужно:
#Взять картинку и найти там хоть какой-то текст
#Выделить его
# Обрезать его полностью 
#Определить средний цвет текста
#Эроднуть выделенный цвет. Обрезать всё к хуям вне этих пикселей. (Это на цветных только)
#
#На черно белых - потыкаться с обрезаниями и т.д.
# Найти наибольшее скопление белого без полосок и тд.
#Там поискать текст. Если он там - выделяем и пытаемся его в текстовой формат перевести.

#https://github.com/AsiriAmalk/Comic_Speech_Bubble_Identifier_Using_Pytesseract
#https://github.com/harikc456/speech-bubble-extraction
#Это можно для баблов, потом нарезав их на баблы, уже можно искать в них текст.
#Для манхвы придётся извернуться, чтобы детектить там текст в них.
image_balls = cv2.imread('../db/makima.png', cv2.IMREAD_GRAYSCALE)

row, col = image_balls.shape[:2]
bottom = image_balls[row-2:row, 0:col]
mean = cv2.mean(bottom)[0]

border_size = 100
border = cv2.copyMakeBorder(
    image_balls,
    top=border_size,
    bottom=border_size,
    left=border_size,
    right=border_size,
    borderType=cv2.BORDER_CONSTANT,
    value=[255, 255, 255]
)

thresh = 100
im_bw = cv2.threshold(border, thresh, 255, cv2.THRESH_BINARY)[1]

thresh = cv2.adaptiveThreshold(
        im_bw, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2
    )

kernel = np.ones((3, 3), np.uint8)
dilated = cv2.dilate(thresh, kernel, iterations=1)
eroded = cv2.erode(dilated, kernel, iterations=1)

magem = cv2.bitwise_not(eroded)

letter_boxes = pytesseract.image_to_boxes(magem,lang='eng')

height, width = magem.shape

for box in letter_boxes.splitlines():
    box = box.split()
    x,y,w,h = int(box[1]),int(box[2]),int(box[3]),int(box[4])
    cv2.rectangle(magem, (x, height - y), (w, height - h), (0,0,255), 3)
    cv2.putText(magem, box[0], (x,height-h+32), cv2.FONT_HERSHEY_COMPLEX,1,(0,255,0),2)
    print(box)
    
cv2.imshow("window", magem)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#       1 #Что нужно:
#       2 #Взять картинку и найти там хоть какой-то текст
#       3 #Выделить его
#    (...)
#      14 #Это можно для баблов, потом нарезав их на баблы, уже можно искать в них текст.
#      15 #Для манхвы придётся извернуться, чтобы детектить там текст в них.
# ---> 16 image_balls = cv2.imread('../db/makima.png', cv2.IMREAD_GRAYSCALE)
#      18 row, col = image_balls.shape[:2]
#      19 bottom = image_balls[row-2:row, 0:col]
#
# NameError: name 'cv2' is not defined
